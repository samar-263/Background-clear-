# %%
from rembg import remove
from PIL import Image
# Out:
# C:\Users\samar\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
input_path = r"C:\Users\samar\Downloads\BIKE1 (1).png"

# %%
input_path
# Out:
# 'C:\\Users\\samar\\Downloads\\BIKE1 (1).png'

# %%
output_path =r"C:\Users\samar\OneDrive\Pictures\Screenshots\BIKE (1).png"

# %%
input = Image.open(input_path)
input
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=480x480>

# %%
output = remove(input)

# %%
output_rgba = output.convert("RGBA")
output_rgba.save(output_path)

# %%
output_rgba
# Out:
# <PIL.Image.Image image mode=RGBA size=480x480>
